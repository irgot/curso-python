# %%
# !dir
# Out:
#  O volume na unidade C não tem nome.
#  O Número de Série do Volume é AA16-9DBD
#
#  Pasta de C:\Users\igors
#
# 21/09/2020  22:56    <DIR>          .
# 21/09/2020  22:56    <DIR>          ..
# 18/07/2020  16:16    <DIR>          .android
# 02/07/2020  00:49    <DIR>          .AndroidStudio4.0
# 30/07/2020  20:57                90 .angular-config.json
# 03/07/2020  22:55               103 .bashrc
# 12/08/2020  18:42             4.828 .bash_history
# 21/07/2020  11:18             3.594 .bash_profile
# 21/09/2020  22:44    <DIR>          .conda
# 21/09/2020  22:48                43 .condarc
# 02/07/2020  00:56    <DIR>          .config
# 03/07/2020  00:10                16 .emulator_console_auth_token
# 04/08/2020  19:04                53 .git-for-windows-updater
# 18/07/2020  16:13                46 .gitconfig
# 03/07/2020  00:32    <DIR>          .gradle
# 21/09/2020  22:56    <DIR>          .ipynb_checkpoints
# 21/09/2020  22:40    <DIR>          .ipython
# ...
