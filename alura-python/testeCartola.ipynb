# %%
import pandas as pd
from requests import request,get

# %%
url_mercado='https://api.cartolafc.globo.com/atletas/mercado'
mercado = get(url_mercado)

mercado = mercado.json()

posicoes =  mercado['posicoes']
status =  mercado['status']
clubes =  mercado['clubes']
atletas = pd.DataFrame(mercado['atletas'])

# del data['apelido']
# del data['foto']

# %%
try:
    del atletas['nome']
    del atletas['scout']
    del atletas['foto']    
except:
    pass

atletas_provaveis=atletas[atletas.status_id==7].sort_values(by='media_num',ascending=False)
atletas_provaveis.head()
# Out:
#                 slug          apelido  atleta_id  rodada_id  clube_id  \
# 42           marinho          Marinho      68952         12       277
# 305  thiago-galhardo  Thiago Galhardo      71844         12       285
# 311   matheus-ferraz   Matheus Ferraz      38632         12       266
# 342          saravia          Saravia      96725         12       285
# 596      victor-luis      Victor Luis      86410         12       263
#
#      posicao_id  status_id  pontos_num  preco_num  variacao_num  media_num  \
# 42            5          7         9.7      24.72          1.46      10.75
# 305           4          7         9.9      18.59          1.74       9.38
# 311           3          7         9.2       6.58          0.58       9.20
# 342           2          7         0.0      18.78          0.00       7.96
# 596           2          7        13.5      11.60          2.23       7.47
#
#      jogos_num
# 42          12
# 305         11
# 311          1
# 342          8
# ...

# %%
pontos_json=[]
index=0
for index,atleta in atletas_provaveis.iterrows():
    # print(atleta.atleta_id)
    
    atleta_id=atleta.atleta_id
    url_pontuacao='https://api.cartolafc.globo.com/auth/mercado/atleta/' + str(atleta_id) + '/pontuacao'
    header={'authorization':'Bearer eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJXLUppTjhfZXdyWE9uVnJFN2lfOGpIY28yU1R4dEtHZF94aW01R2N4WS1ZIn0.....grMc3yNeoqlJ_C4WB6v6eYG4WTm0XYclZJUCuXm8ZColacAi1k2h7la93gZS7Afft0BrCS1_LVixjCz6PswaGALYqUhkpzB2AGIw18QZDmKkeLgT4Ocj5s1O5ITh7XnpyPfAN5NszDjzW6lQemULUGZakBO2l58ML2Bpb0uf_-pcIHnP1cJa4BxYRyEPWCimW3cwHRNc00hgb_z5_UF529_vnMMtujZp9PL-eZpiN3H-vJZ3Ed7W4Lb2NQy1QNaOS3eEGn2eSl4P_gNwq6vx9r7y1yH2KHn-Wo8lSARpgwogcpgNrPVeXKB16WVegIy3v5bztrcriK1wVYbKLSd2iw'}
    try:
        pontuacao = get(url_pontuacao,headers=header)
        for atleta_r in pontuacao.json():
            pontos_json.append(atleta_r)
    except:
        pass

# %%
pontos=pd.DataFrame()
pontos=pd.DataFrame(pontos_json).reset_index()
pontos.head()
# Out:
#    index  atleta_id  rodada_id  pontos  preco  variacao  media
# 0      0      68952          1    11.7  12.10      7.10  11.70
# 1      1      68952          2     6.2  15.16      3.06   8.95
# 2      2      68952          3    23.0  21.62      6.46  13.63
# 3      3      68952          4    13.9  22.50      0.88  13.70
# 4      4      68952          5     3.8  21.07     -1.43  11.72

# %%
clubesDF = pd.DataFrame(clubes).T
clubesDF.head()
# Out:
#       id         nome abreviacao  \
# 262  262     Flamengo        FLA
# 263  263     Botafogo        BOT
# 264  264  Corinthians        COR
# 265  265        Bahia        BAH
# 266  266   Fluminense        FLU
#
#                                                escudos nome_fantasia
# 262  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...      Flamengo
# 263  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...      Botafogo
# 264  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...   Corinthians
# 265  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...         Bahia
# 266  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...    Fluminense

# %%
ultima_rodada=atletas_provaveis['rodada_id'].max()
url_partida_atual = 'https://api.cartolafc.globo.com/partidas/'+str(ultima_rodada+1)
partida_atual_response = get(url_partida_atual,headers=header)
partida_atual=partida_atual_response.json()['partidas']
partidas=[]

for i in range(ultima_rodada,0,-1):
    url_partida='https://api.cartolafc.globo.com/partidas/'+str(i)
    partidas_response=get(url_partida,headers=header)
    for partida_json in partidas_response.json()['partidas']:
        partida_json['rodada']=i
        partidas.append(partida_json)

# %%
partidasDF=pd.DataFrame(partidas)
partidasDF[partidasDF.clube_casa_id==266].sort_values(by='rodada')
# Out:
#      partida_id  clube_casa_id  clube_casa_posicao  clube_visitante_id  \
# 100      243073            266                   7                 275
# 90       243093            266                   7                 285
# 60       243143            266                   7                 267
# 50       243163            266                   7                 373
# 30       243203            266                   7                 262
# 20       243214            266                   7                 264
# 0        243254            266                   7                 294
#
#     aproveitamento_mandante aproveitamento_visitante  clube_visitante_posicao  \
# 100         [d, d, v, d, v]          [v, v, e, e, e]                        4
# 90          [d, d, v, d, v]          [e, v, d, d, e]                        2
# 60          [d, d, v, d, v]          [v, d, v, d, e]                        5
# 50          [d, d, v, d, v]          [e, v, v, d, e]                       13
# ...

# %%
partida_atualDF=pd.DataFrame(partida_atual)
partida_atualDF
# Out:
#    partida_id  clube_casa_id  clube_casa_posicao  clube_visitante_id  \
# 0      243273            262                   6                 293
# 1      243274            263                  18                 266
# 2      243275            275                   4                 354
# 3      243276            280                  17                 264
# 4      243277            282                   1                 267
# 5      243278            284                  14                 285
# 6      243279            265                  20                 292
# 7      243280            294                  16                 276
# 8      243281            356                  10                 373
# 9      243282            290                  19                 277
#
#   aproveitamento_mandante aproveitamento_visitante  clube_visitante_posicao  \
# 0         [v, v, v, d, e]          [e, d, e, v, v]                       11
# ...

# %%
clubesDF
# clubesDF['media_visitante']
# clubesDF['media_em_casa']
# clubesDF['media']
#clubesDF.sort_values(by='id',inplace=True)
#clubesDF.set_index('id',inplace=True)
clubesDF['partidas_em_casa']=partidasDF.groupby('clube_casa_id')['rodada'].apply(list).reset_index(name='partidas_em_casa').rename(columns={'clube_casa_id':'id'}).set_index('id')
clubesDF['partidas_visitante']=partidasDF.groupby('clube_visitante_id')['rodada'].apply(list).reset_index(name='partidas_visitante').rename(columns={'clube_visitante_id':'id'}).set_index('id')
#clubesDF
# partidasDF.groupby('clube_casa_id')['rodada'].apply(list).reset_index(name='partidas_em_casa').rename(columns={'clube_casa_id':'id'}).set_index('id')

clubesDF
# clubesDF[clubesDF.id==262]['partidas_casa']
# Out:
#       id           nome abreviacao  \
# 262  262       Flamengo        FLA
# 263  263       Botafogo        BOT
# 264  264    Corinthians        COR
# 265  265          Bahia        BAH
# 266  266     Fluminense        FLU
# 267  267          Vasco        VAS
# 275  275      Palmeiras        PAL
# 276  276      São Paulo        SAO
# 277  277         Santos        SAN
# 280  280     Bragantino        BGT
# 282  282    Atlético-MG        ATL
# 284  284         Grêmio        GRE
# 285  285  Internacional        INT
# 290  290          Goiás        GOI
# 292  292          Sport        SPO
# 293  293   Athlético-PR        CAP
# 294  294       Coritiba        CFC
# 354  354          Ceará        CEA
# 356  356      Fortaleza        FOR
# 373  373    Atlético-GO        ACG
#
#                                                escudos  nome_fantasia  \
# 262  {'60x60': 'https://s.glbimg.com/es/sde/f/organ...       Flamengo
# ...

# %%
pontos
# Out:
#       index  atleta_id  rodada_id  pontos  preco  variacao  media
# 0         0      68952          1    11.7  12.10      7.10  11.70
# 1         1      68952          2     6.2  15.16      3.06   8.95
# 2         2      68952          3    23.0  21.62      6.46  13.63
# 3         3      68952          4    13.9  22.50      0.88  13.70
# 4         4      68952          5     3.8  21.07     -1.43  11.72
# ...     ...        ...        ...     ...    ...       ...    ...
# 2671   2671      62129          8     0.0   1.51      0.00  -1.36
# 2672   2672      62129          9     0.0   1.51      0.00  -1.36
# 2673   2673      62129         10    -2.6   1.02     -0.49  -1.57
# 2674   2674      62129         11     0.0   1.02      0.00  -1.57
# 2675   2675      62129         12    -0.6   1.18      0.16  -1.43
#
# [2676 rows x 7 columns]

# %%
colunas={'pontos_num':'pontos','preco_num':'preco','variacao_num':'variacao','media_num':'media'}
ap = atletas_provaveis[['atleta_id','rodada_id','pontos_num','preco_num','variacao_num','media_num']].rename(columns=colunas)
pontos_c = pd.concat([ap,pontos],ignore_index=True)
pontos[pontos.rodada_id==12]
# Out:
#       index  atleta_id  rodada_id  pontos  preco  variacao  media
# 11       11      68952         12     9.7  24.72      1.46  10.75
# 23       23      71844         12     9.9  18.59      1.74   9.38
# 35       35      38632         12     9.2   6.58      0.58   9.20
# 47       47      96725         12     0.0  18.78      0.00   7.96
# 59       59      86410         12    13.5  11.60      2.23   7.47
# ...     ...        ...        ...     ...    ...       ...    ...
# 2627   2627      71631         12     0.0   6.70      0.00  -0.44
# 2639   2639      88916         12     0.0   4.97      0.00  -0.46
# 2651   2651      38545         12     0.0   5.93      0.00  -0.80
# 2663   2663      84382         12     1.3   2.83      0.66  -1.34
# 2675   2675      62129         12    -0.6   1.18      0.16  -1.43
#
# [223 rows x 7 columns]

# %% [markdown]
# ### Populando visitante e posicao

# %%
pontos_new = atletas.merge(pontos, on='atleta_id')[['atleta_id','apelido','rodada_id_y','pontos','preco','variacao','media','clube_id','posicao_id']]
pontos_new = pontos_new.merge(right = partidasDF, how='left',  left_on=['rodada_id_y','clube_id'], right_on=['rodada','clube_visitante_id'])[['atleta_id','apelido','rodada_id_y','pontos','preco','variacao','media','clube_id','posicao_id','clube_visitante_id']]
pontos_new['clube_visitante_id'] = pontos_new.clube_visitante_id.fillna(False)
pontos_new['visitante']=pontos_new['clube_visitante_id'].astype(bool)
pontos_new.drop(columns=['clube_visitante_id'],inplace=True)
pontos_new.head()
# Out:
#    atleta_id apelido  rodada_id_y  pontos  preco  variacao  media  clube_id  \
# 0      80370  Edson             1     0.0   4.00      0.00   0.00       373
# 1      80370  Edson             2     7.7   6.37      2.37   7.70       373
# 2      80370  Edson             3     1.2   5.79     -0.58   4.45       373
# 3      80370  Edson             4     5.5   7.02      1.23   4.80       373
# 4      80370  Edson             5     6.3   7.81      0.79   5.18       373
#
#    posicao_id  visitante
# 0           4       True
# 1           4      False
# 2           4      False
# 3           4       True
# 4           4       True

# %%
pd.set_option('display.max_rows', 200)
pontos_new=pontos_new.merge(right = partida_atualDF, how='left',  left_on=['clube_id'], right_on=['clube_visitante_id'])[['atleta_id','apelido','rodada_id_y','pontos','preco','variacao','media','clube_id','posicao_id','visitante','clube_visitante_posicao','clube_casa_posicao']]
pontos_new.head(200)
# Out:
# 196      90933               Jean            5   -4.00   6.12     -0.73
# 197      90933               Jean            6    5.30   7.73      1.61
# 198      90933               Jean            7    1.80   7.19     -0.54
# 199      90933               Jean            8   -2.40   6.30     -0.89
#
#      media  clube_id  posicao_id  visitante  clube_visitante_posicao  \
# 0     0.00       373           4       True                     13.0
# 1     7.70       373           4      False                     13.0
# 2     4.45       373           4      False                     13.0
# 3     4.80       373           4       True                     13.0
# 4     5.18       373           4       True                     13.0
# 5     5.24       373           4      False                     13.0
# 6     4.88       373           4       True                     13.0
# 7     5.81       373           4      False                     13.0
# ...

# %%
pontos_new['e_visitante_rodada_atual']=pontos_new.clube_id.isin(partida_atualDF.clube_visitante_id)
pontos_new_rodada = pontos_new[(pontos_new.visitante==pontos_new.e_visitante_rodada_atual) & (pontos_new.atleta_id.isin(atletas_provaveis.atleta_id))].groupby(by='apelido').mean().sort_values(by='pontos',ascending=False)

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==1].nlargest(10,'pontos')
# Out:
#                    atleta_id  rodada_id_y     pontos      preco  variacao  \
# apelido
# João Paulo           85425.0     6.000000  10.000000   7.344000  2.116000
# Wilson               50284.0     5.800000   8.100000   8.916000  1.510000
# Gatito Fernández     74061.0     6.500000   5.783333  14.066667  0.770000
# Felipe Alves         72372.0     6.000000   2.740000   3.094000 -0.246000
# Muriel               69041.0     5.800000   2.680000   4.502000  0.270000
# Douglas Friedrich    78584.0     6.166667   2.650000  10.353333  0.181667
# Jean                 90933.0     6.000000   2.250000   6.906667 -0.065000
# Cássio               42234.0     6.666667   2.233333   9.776667 -0.181667
# Vanderlei            62121.0     6.333333   1.466667   8.623333 -0.046667
# Tadeu                82453.0     6.000000   1.083333   7.916667 -0.345000
#
#                       media  clube_id  posicao_id  visitante  \
# apelido
# João Paulo         7.324000     277.0         1.0        1.0
# ...

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==2].nlargest(10,'pontos')
# Out:
#                   atleta_id  rodada_id_y    pontos      preco  variacao  \
# apelido
# Felipe Jonatan     101708.0     6.000000  7.200000  11.050000  0.704000
# Guga               101319.0     6.666667  5.366667  13.631667  0.818333
# Gabriel Dias        88368.0     6.000000  4.960000   6.958000  1.160000
# Saravia             96725.0     6.333333  4.250000  18.996667  0.736667
# Guilherme Arana     87228.0     6.666667  3.933333  16.886667  0.123333
# Bruno Cortez        72079.0     6.333333  3.433333  10.495000  0.720000
# Moisés              90444.0     6.333333  3.416667  10.765000  0.433333
# Bruno Pacheco       90061.0     6.000000  3.400000   7.224000  0.082000
# Juninho Capixaba    94968.0     6.166667  3.266667   7.566667  0.371667
# Abner Vinícius     104513.0     5.800000  3.240000   9.312000  1.254000
#
#                       media  clube_id  posicao_id  visitante  \
# apelido
# Felipe Jonatan     5.306000     277.0         2.0        1.0
# ...

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==3].nlargest(10,'pontos')
# Out:
#                     atleta_id  rodada_id_y    pontos      preco  variacao  \
# apelido
# Sabino               104075.0     5.800000  4.720000   6.088000  0.328000
# Júnior Alonso         88312.0     6.666667  4.700000  11.245000  0.896667
# Iago Maidana          89226.0     6.166667  4.500000   5.986667  0.903333
# Paulão                63172.0     6.000000  3.700000   2.368000  0.204000
# Kanu                  98484.0     6.500000  3.583333   4.210000  0.378333
# Gustavo Gómez         71684.0     6.333333  3.250000  13.523333  0.015000
# Marcelo Benevenuto    95638.0     6.500000  3.000000   6.666667  0.203333
# Ernando               49651.0     6.166667  2.850000   6.315000  0.636667
# Luan Peres            84847.0     6.000000  2.760000   5.782000  0.104000
# Jackson               70934.0     6.000000  2.400000   3.594000  0.208000
#
#                        media  clube_id  posicao_id  visitante  \
# apelido
# Sabino              3.138000     294.0         3.0        0.0
# ...

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==4].nlargest(10,'pontos')
# Out:
#                  atleta_id  rodada_id_y    pontos      preco  variacao  \
# apelido
# Rodriguinho        61033.0     6.166667  4.916667  15.621667 -0.316667
# Thiago Galhardo    71844.0     6.333333  4.850000  14.436667  0.078333
# Fernando Sobral    84428.0     6.000000  4.800000  10.884000  0.808000
# Jair               81091.0     6.666667  4.483333   7.371667  0.861667
# Bruno Tubarão      93637.0     6.000000  3.880000   2.402000  0.560000
# Franco             39656.0     6.666667  3.666667   4.625000  0.350000
# Daniel Bessa      103591.0     6.000000  3.366667   6.751667  0.371667
# Alisson            81845.0     6.333333  3.283333   9.926667 -0.061667
# Ramiro             78715.0     6.666667  3.266667   6.680000  0.253333
# Léo Cittadini      70986.0     5.800000  3.200000  13.228000  0.898000
#
#                     media  clube_id  posicao_id  visitante  \
# apelido
# Rodriguinho      5.945000     265.0         4.0        0.0
# ...

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==5].nlargest(10,'pontos')
# Out:
#                      atleta_id  rodada_id_y     pontos      preco  variacao  \
# apelido
# Alerrandro            101715.0     6.000000  10.540000  10.734000  1.814000
# Marinho                68952.0     6.000000   7.580000  21.038000  0.312000
# Keno                   86485.0     6.666667   7.283333  10.291667  0.160000
# Wellington Paulista    38279.0     6.000000   5.640000   7.576000  0.678000
# Claudinho              92630.0     6.000000   5.120000  13.426000  0.564000
# Matheus Babi           94444.0     6.500000   4.950000   6.885000  0.260000
# Élber                  74140.0     6.166667   4.933333   8.946667  0.676667
# Cano                   79631.0     6.500000   4.933333  12.421667  0.158333
# Romarinho              84523.0     6.000000   3.920000   7.938000  0.500000
# Talles Magno          105786.0     6.500000   3.900000  10.106667  0.443333
#
#                          media  clube_id  posicao_id  visitante  \
# apelido
# ...

# %%
pontos_new_rodada[pontos_new_rodada['posicao_id']==6].nlargest(10,'pontos')
# Out:
#                    atleta_id  rodada_id_y    pontos      preco      variacao  \
# apelido
# Jorge Sampaoli       70800.0     6.666667  5.395000  14.023333  6.800000e-01
# Jorginho             70323.0     5.800000  4.540000   7.240000  7.233333e-01
# Cuca                 42411.0     6.000000  4.476000  10.138000  1.120000e-01
# Maurício Barbieri    82792.0     6.000000  3.805000   5.835000  5.000000e-02
# Rogério Ceni         97341.0     6.000000  3.746000   6.312000  7.000000e-02
# Ramon Menezes        96767.0     6.500000  3.390000   9.233333  1.750000e-01
# Paulo Autuori        36943.0     6.500000  3.145000   8.276667  2.133333e-01
# Guto Ferreira        37245.0     6.000000  2.978000   7.252000 -2.220446e-17
# Renato Gaúcho        41929.0     6.333333  2.891667  12.281667 -1.983333e-01
# Odair Hellmann       92273.0     5.800000  2.870000   8.200000 -1.440000e-01
#
#                       media  clube_id  posicao_id  visitante  \
# apelido
# ...
